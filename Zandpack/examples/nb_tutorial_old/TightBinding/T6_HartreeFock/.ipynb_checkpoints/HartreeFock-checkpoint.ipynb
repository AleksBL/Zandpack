# %%
import sisl
import numpy as np
from ase import Atoms
from ase.build import molecule
from ase.collections import g2
from ase.visualize import view
import matplotlib.pyplot as plt

# %%
A = molecule('C6H6')
for i in range(6):
    A.pop(6)

# %%
M = sisl.Geometry.fromASE(A)

# %%
sisl.plot(M); plt.axis('equal')
# Out:
# (-1.3291520000000001, 1.3291520000000001, -1.5347728, 1.5347728)

# %%
sisl.orbital
# Out:
# <module 'sisl.orbital' from '/home/aleksander/.local/lib/python3.9/site-packages/sisl/orbital.py'>
