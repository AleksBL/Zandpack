# %%
import sisl
from Zandpack.TimedependentTransport import TD_Transport as TDT
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np

# %% [markdown]
# Here we construct a more complicated example. Its an example of the realspace self energy used on doped graphene. Beyond this there is a gold STM tip above it.
